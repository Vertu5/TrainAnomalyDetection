# %%
import pandas as pd

df = pd.read_csv('ar41_for_ulb_mini.csv',sep=";")

print (df.head)
# Out:
# <bound method NDFrame.head of     Unnamed: 0  mapped_veh_id       timestamps_UTC        lat       lon  \
# 0            0            181  2023-08-01 03:44:12  50.769818  3.872114
# 1            1            143  2023-08-01 06:36:29  51.039993  3.693429
# 2            2            183  2023-08-24 06:53:54  50.742203  3.602035
# 3            3            177  2023-08-01 13:53:38  50.930914  5.327132
# 4            4            143  2023-08-24 07:02:30  51.180773  3.575259
# ..         ...            ...                  ...        ...       ...
# 95          95            181  2023-08-24 05:26:20  51.149477  4.521748
# 96          96            121  2023-08-24 05:26:38  50.466237  3.948079
# 97          97            159  2023-08-24 05:28:50  50.788946  3.869880
# 98          98            179  2023-08-24 05:34:59  51.159618  4.664623
# 99          99            121  2023-08-24 05:40:30  50.461220  3.948056
#
#     RS_E_InAirTemp_PC1  RS_E_InAirTemp_PC2  RS_E_OilPress_PC1  \
# 0                 27.0                23.0              255.0
# 1                 33.0                32.0              272.0
# 2                 31.0                33.0              234.0
# 3                 35.0                38.0              220.0
# 4                 41.0                34.0              227.0
# ..                 ...                 ...                ...
# 95                48.0                41.0              213.0
# 96                40.0                36.5              217.0
# 97                35.0                26.0              324.0
# 98                38.0                40.0              396.0
# 99                40.0                36.0              217.0
#
#     RS_E_OilPress_PC2  RS_E_RPM_PC1  RS_E_RPM_PC2  RS_E_WatTemp_PC1  \
# 0               238.0         794.0         801.0              83.0
# 1               324.0         802.0         804.0              78.0
# 2               182.0         799.0         802.0              82.0
# 3               244.0         794.0         801.0              77.0
# 4               282.0         806.0         800.0              85.0
# ..                ...           ...           ...               ...
# 95              196.0         799.0         797.0              87.0
# 96              213.0         789.0         800.5              86.5
# 97              414.0        1316.0        1331.0              82.0
# 98              372.0        1981.0        1956.0              82.0
# 99              217.0         814.0         808.0              85.0
#
#     RS_E_WatTemp_PC2  RS_T_OilTemp_PC1  RS_T_OilTemp_PC2
# 0               81.0              76.0              77.0
# 1               78.0              73.0              74.0
# 2               82.0              85.0              87.0
# 3               81.0              78.0              82.0
# 4               78.0              82.0              79.0
# ..               ...               ...               ...
# 95              89.0              81.0              87.0
# 96              87.0              85.5              84.5
# 97              84.0              84.0              87.0
# 98              83.0              82.0              84.0
# 99              81.0              87.0              86.0
#
# [100 rows x 15 columns]>

# %%
# Visiualize data 
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("darkgrid")
sns.set_context("paper")

plt.figure(figsize=(15,10))
for i in range(3, 15):
    plt.subplot(3, 5, i)
    sns.scatterplot(x='mapped_veh_id', y=df.columns[i], data=df, sizes=(50, 200))
    plt.title(df.columns[i])
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler


# Check for and handle missing values
df = df.dropna()

# Check for and handle duplicate rows
df = df.drop_duplicates()
